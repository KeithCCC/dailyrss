# %%
import requests
from bs4 import BeautifulSoup
from rdflib import Graph
import feedparser

# %%
def extract_urls_title(website_url):
    response = requests.get(website_url)
    soup = BeautifulSoup(response.content, 'html.parser')

    rss_urls = []
    for link in soup.find_all('link', type='application/rss+xml'):
        rss_urls.append([link.get('title'), link.get('href')])

    return rss_urls

# %%
l = extract_urls_title("https://win-tab.net/")
feeds = []
with open('rss.txt','w') as f:
    for url in l:
        feed = feedparser.parse(url[1])
        feeds.append(feed)
    for feed in feeds:
        print("base url:"+feed.feed.link)
        for entry in feed.entries:
            print("each link:"+entry.link, end="\n\n", file=f)
            if 'published' in entry:
                print("published:"+ entry.published, end="\n\n", file=f)
            print("title:" + entry.title, end="\n\n", file=f)
            print("link:" + entry.link, end="\n\n", file=f)
            print('---------------------------------', end="\n\n", file=f)
# Out:
# base url:https://win-tab.net
# base url:https://win-tab.net
# base url:https://win-tab.net

# %%
entry

# %%
from IPython.core.interactiveshell import InteractiveShell # type: ignore
InteractiveShell.ast_node_interactivity = "all"

# %%
l = extract_urls_title("https://win-tab.net/")
feeds = []
for url in l:
    feed = feedparser.parse(url[1])
    feeds.append(feed)
for feed in feeds:
    print("base url:"+feed.feed.link)
    for entry in feed.entries:
        print("each link:"+entry.link)
        if 'published' in entry:
            print('published:  '+ entry.published)
        print('title:  '+ entry.title)
        print('link:  '+ entry.link)
        if 'content' in entry:
            content_str = ''.join([str(c) for c in entry.content])
            print('content:  ' + content_str)
        print('---------------------------------')
# Out:
# base url:https://win-tab.net
# each link:https://win-tab.net/dynabook/dynabook_ga_zy_2409033/
# published:  Tue, 03 Sep 2024 14:47:14 +0000
# title:  dynabook GA/ZY － DynabookがCPUにRyzenを搭載するモバイルノートを発売！重さ1キロ切りの超軽量タイプです。しかも格安！
# link:  https://win-tab.net/dynabook/dynabook_ga_zy_2409033/
# ---------------------------------
# each link:https://win-tab.net/imported/geekom_mini_air12_sale_2409032/
# published:  Tue, 03 Sep 2024 10:58:41 +0000
# title:  GEEKOMのミニPC、MINI AIR12がセール中、Windows 11 Pro/Intel N100/16GB/512GBというスペックで32,000円です！
# link:  https://win-tab.net/imported/geekom_mini_air12_sale_2409032/
# ---------------------------------
# each link:https://win-tab.net/acc/ktc_h25t7_review_2409031/
# published:  Tue, 03 Sep 2024 02:01:56 +0000
# title:  KTC H25T7 レビュー － 24.5インチFHD解像度、リフレッシュレート180Hzで13,000円台で購入できる、ハイコスパなPCモニター（ゲーミングモニター）
# link:  https://win-tab.net/acc/ktc_h25t7_review_2409031/
# ---------------------------------
# each link:https://win-tab.net/misc/junk_diary_2409023/
# published:  Mon, 02 Sep 2024 08:54:19 +0000
# title:  ジャンク日記（9月2日）ー ThinkPad X1 Carbon Gen 9のジャンク品を購入！憧れのThinkPadフラッグシップもジャンクなら安い！はメーカー保証が･･･
# link:  https://win-tab.net/misc/junk_diary_2409023/
# ---------------------------------
# each link:https://win-tab.net/acc/sanwa_ma_btring5bk_2409022/
# published:  Mon, 02 Sep 2024 05:47:39 +0000
# title:  サンワサプライ Bluetooth リングマウス MA-BTRING5BK － 親指ひとつで操作できる「空中リングマウス」にホイールがつきました
# link:  https://win-tab.net/acc/sanwa_ma_btring5bk_2409022/
# ---------------------------------
# each link:https://win-tab.net/opinion/hyper_threading_technology_2409021/
# published:  Mon, 02 Sep 2024 03:19:48 +0000
# title:  ハイパースレッディングが無くなる？Intel次世代CPUへの影響
# link:  https://win-tab.net/opinion/hyper_threading_technology_2409021/
# ---------------------------------
# each link:https://win-tab.net/imported/geekom_gt13_pro_review_2409013/
# published:  Sun, 01 Sep 2024 13:50:59 +0000
# title:  GEEKOM GT13 Pro レビュー － Core i9-13900Hを搭載し、高負荷な作業もこなせるミニPC。ポートも充実！
# link:  https://win-tab.net/imported/geekom_gt13_pro_review_2409013/
# ---------------------------------
# each link:https://win-tab.net/android/iiif150_air3_2409012/
# published:  Sun, 01 Sep 2024 11:06:38 +0000
# title:  IIIF150 Air3 － タフネススマホながら厚さはわずかに10.5 mm！独創的なデザインも魅力です！
# link:  https://win-tab.net/android/iiif150_air3_2409012/
# ---------------------------------
# each link:https://win-tab.net/imported/beelink_gti14_ultra_2409011/
# published:  Sun, 01 Sep 2024 05:40:49 +0000
# title:  Beelink GTi14 Ultra / Multi-Functional EX Docking Station － グラフィックカードの接続ができる高性能ミニPCとドッキングステーション
# link:  https://win-tab.net/imported/beelink_gti14_ultra_2409011/
# ---------------------------------
# each link:https://win-tab.net/hp/hp_mobile_note_pcs_2408313/
# published:  Sat, 31 Aug 2024 14:07:52 +0000
# title:  20万円以下で買えるHPのモバイルノートをピックアップしてみました！超軽量なPavilion Aero 13や強力なセキュリティ機能を備えたEliteBook 630 G11など
# link:  https://win-tab.net/hp/hp_mobile_note_pcs_2408313/
# ---------------------------------
# base url:https://win-tab.net
# each link:https://win-tab.net/dynabook/dynabook_ga_zy_2409033/
# published:  Tue, 03 Sep 2024 14:47:14 +0000
# title:  dynabook GA/ZY － DynabookがCPUにRyzenを搭載するモバイルノートを発売！重さ1キロ切りの超軽量タイプです。しかも格安！
# link:  https://win-tab.net/dynabook/dynabook_ga_zy_2409033/
# ---------------------------------
# each link:https://win-tab.net/imported/geekom_mini_air12_sale_2409032/
# published:  Tue, 03 Sep 2024 10:58:41 +0000
# title:  GEEKOMのミニPC、MINI AIR12がセール中、Windows 11 Pro/Intel N100/16GB/512GBというスペックで32,000円です！
# link:  https://win-tab.net/imported/geekom_mini_air12_sale_2409032/
# ---------------------------------
# each link:https://win-tab.net/acc/ktc_h25t7_review_2409031/
# published:  Tue, 03 Sep 2024 02:01:56 +0000
# title:  KTC H25T7 レビュー － 24.5インチFHD解像度、リフレッシュレート180Hzで13,000円台で購入できる、ハイコスパなPCモニター（ゲーミングモニター）
# link:  https://win-tab.net/acc/ktc_h25t7_review_2409031/
# ---------------------------------
# each link:https://win-tab.net/misc/junk_diary_2409023/
# published:  Mon, 02 Sep 2024 08:54:19 +0000
# title:  ジャンク日記（9月2日）ー ThinkPad X1 Carbon Gen 9のジャンク品を購入！憧れのThinkPadフラッグシップもジャンクなら安い！はメーカー保証が･･･
# link:  https://win-tab.net/misc/junk_diary_2409023/
# ---------------------------------
# each link:https://win-tab.net/acc/sanwa_ma_btring5bk_2409022/
# published:  Mon, 02 Sep 2024 05:47:39 +0000
# title:  サンワサプライ Bluetooth リングマウス MA-BTRING5BK － 親指ひとつで操作できる「空中リングマウス」にホイールがつきました
# link:  https://win-tab.net/acc/sanwa_ma_btring5bk_2409022/
# ---------------------------------
# each link:https://win-tab.net/opinion/hyper_threading_technology_2409021/
# published:  Mon, 02 Sep 2024 03:19:48 +0000
# title:  ハイパースレッディングが無くなる？Intel次世代CPUへの影響
# link:  https://win-tab.net/opinion/hyper_threading_technology_2409021/
# ---------------------------------
# each link:https://win-tab.net/imported/geekom_gt13_pro_review_2409013/
# published:  Sun, 01 Sep 2024 13:50:59 +0000
# title:  GEEKOM GT13 Pro レビュー － Core i9-13900Hを搭載し、高負荷な作業もこなせるミニPC。ポートも充実！
# link:  https://win-tab.net/imported/geekom_gt13_pro_review_2409013/
# ---------------------------------
# each link:https://win-tab.net/android/iiif150_air3_2409012/
# published:  Sun, 01 Sep 2024 11:06:38 +0000
# title:  IIIF150 Air3 － タフネススマホながら厚さはわずかに10.5 mm！独創的なデザインも魅力です！
# link:  https://win-tab.net/android/iiif150_air3_2409012/
# ---------------------------------
# each link:https://win-tab.net/imported/beelink_gti14_ultra_2409011/
# published:  Sun, 01 Sep 2024 05:40:49 +0000
# title:  Beelink GTi14 Ultra / Multi-Functional EX Docking Station － グラフィックカードの接続ができる高性能ミニPCとドッキングステーション
# link:  https://win-tab.net/imported/beelink_gti14_ultra_2409011/
# ---------------------------------
# each link:https://win-tab.net/hp/hp_mobile_note_pcs_2408313/
# published:  Sat, 31 Aug 2024 14:07:52 +0000
# title:  20万円以下で買えるHPのモバイルノートをピックアップしてみました！超軽量なPavilion Aero 13や強力なセキュリティ機能を備えたEliteBook 630 G11など
# link:  https://win-tab.net/hp/hp_mobile_note_pcs_2408313/
# ---------------------------------
# base url:https://win-tab.net
# each link:https://win-tab.net/misc/junk_diary_2409023/#comment-62423
# published:  Tue, 03 Sep 2024 09:49:43 +0000
# title:  匿名 より ジャンク日記（9月2日）ー ThinkPad X1 Carbon Gen 9のジャンク品を購入！憧れのThinkPadフラッグシップもジャンクなら安い！はメーカー保証が･･･ へのコメント
# link:  https://win-tab.net/misc/junk_diary_2409023/#comment-62423
# content:  {'type': 'text/html', 'language': None, 'base': 'https://win-tab.net/comments/feed/', 'value': '<p>かのあゆさん、返信ありがとうございます！</p>'}
# ---------------------------------
# each link:https://win-tab.net/android/leeco_eui6_1802032/#comment-62414
# published:  Tue, 03 Sep 2024 04:37:03 +0000
# title:  Hd Streamz より LeEco Le Max 2 ー カスタムROMを導入して”非公式版”EUI 6.0にアップグレードしてみたよ（かのあゆ） へのコメント
# link:  https://win-tab.net/android/leeco_eui6_1802032/#comment-62414
# content:  {'type': 'text/html', 'language': None, 'base': 'https://win-tab.net/comments/feed/', 'value': '<p>このカスタムROMの導入手順がとても参考になりました！EUI 6.0の新機能が楽しみです。ありがとうございます！</p>'}
# ---------------------------------
# each link:https://win-tab.net/misc/junk_diary_2409023/#comment-62406
# published:  Mon, 02 Sep 2024 23:50:18 +0000
# title:  かのあゆブラック より ジャンク日記（9月2日）ー ThinkPad X1 Carbon Gen 9のジャンク品を購入！憧れのThinkPadフラッグシップもジャンクなら安い！はメーカー保証が･･･ へのコメント
# link:  https://win-tab.net/misc/junk_diary_2409023/#comment-62406
# content:  {'type': 'text/html', 'language': None, 'base': 'https://win-tab.net/comments/feed/', 'value': '<
://win-tab.net/android/oukitel_rt7_titan_5g_2308062/#comment-62229
# published:  Fri, 30 Aug 2024 05:17:48 +0000
# title:  HB より OUKITEL RT7 Titan 5G － やべえ、欲しい！現時点で最強のタフネスタブレット（人によっては最凶かも…） へのコメント
# link:  https://win-tab.net/android/oukitel_rt7_titan_5g_2308062/#comment-62229
# content:  {'type': 'text/html', 'language': None, 'base': 'https://win-tab.net/comments/feed/', 'value': '<p>発売後1年経っていますが、いまＡｍａｚｏｎのスマイルセールで28900円で買えるので買ってしまいました。<br />\nお風呂タブ＆災害用バッテリーとしての活躍を期待しています。</p>'}
# ---------------------------------
# each link:https://win-tab.net/acc/logicool_trackball_2408282/#comment-62228
# published:  Fri, 30 Aug 2024 03:08:14 +0000
# title:  匿名 より Logicool MX ERGO S / ERGO M575SP － トラックボールの「名機」2機種がリニューアル、静音タイプに！ へのコメント
# link:  https://win-tab.net/acc/logicool_trackball_2408282/#comment-62228
# content:  {'type': 'text/html', 'language': None, 'base': 'https://win-tab.net/comments/feed/', 'value': '<p>MX ERGO待望のモデルチェンジ……と思ったら静音ボタン採用と充電口がType-Cになった以外はほとんど据え置きかやや劣化……<br />\nフラグシップモデルを名乗る高級機なのだから、MagSpeedホイールくらいは付けて欲しかったですね</p>'}
# ---------------------------------

# %%
l = extract_urls_title("https://win-tab.net/")
feeds = []
for url in l:
    feed = feedparser.parse(url[1])
    feeds.append(feed)
for feed in feeds:
    print("base url:"+feed.feed.link)
    for entry in feed.entries:
        if 'content' in entry:
            print("each link:"+entry.link)
            if 'published' in entry:
                print('published:  '+ entry.published)
            print('title:  '+ entry.title)
            print('link:  '+ entry.link)
            if 'content' in entry:
                content_str = ''.join([str(c) for c in entry.content])
                print('content:  ' + content_str)
            print('---------------------------------')
# Out:
# base url:https://win-tab.net
# base url:https://win-tab.net
# base url:https://win-tab.net
# each link:https://win-tab.net/misc/junk_diary_2409023/#comment-62423
# published:  Tue, 03 Sep 2024 09:49:43 +0000
# title:  匿名 より ジャンク日記（9月2日）ー ThinkPad X1 Carbon Gen 9のジャンク品を購入！憧れのThinkPadフラッグシップもジャンクなら安い！はメーカー保証が･･･ へのコメント
# link:  https://win-tab.net/misc/junk_diary_2409023/#comment-62423
# content:  {'type': 'text/html', 'language': None, 'base': 'https://win-tab.net/comments/feed/', 'value': '<p>かのあゆさん、返信ありがとうございます！</p>'}
# ---------------------------------
# each link:https://win-tab.net/android/leeco_eui6_1802032/#comment-62414
# published:  Tue, 03 Sep 2024 04:37:03 +0000
# title:  Hd Streamz より LeEco Le Max 2 ー カスタムROMを導入して”非公式版”EUI 6.0にアップグレードしてみたよ（かのあゆ） へのコメント
# link:  https://win-tab.net/android/leeco_eui6_1802032/#comment-62414
# content:  {'type': 'text/html', 'language': None, 'base': 'https://win-tab.net/comments/feed/', 'value': '<p>このカスタムROMの導入手順がとても参考になりました！EUI 6.0の新機能が楽しみです。ありがとうございます！</p>'}
# ---------------------------------
# each link:https://win-tab.net/misc/junk_diary_2409023/#comment-62406
# published:  Mon, 02 Sep 2024 23:50:18 +0000
# title:  かのあゆブラック より ジャンク日記（9月2日）ー ThinkPad X1 Carbon Gen 9のジャンク品を購入！憧れのThinkPadフラッグシップもジャンクなら安い！はメーカー保証が･･･ へのコメント
# link:  https://win-tab.net/misc/junk_diary_2409023/#comment-62406
# content:  {'type': 'text/html', 'language': None, 'base': 'https://win-tab.net/comments/feed/', 'value': '<p><a href="https://win-tab.net/misc/junk_diary_2409023/#comment-62379">匿名</a> への返信。</p>\n<p>&gt;&gt;匿名さん<br />\n元々「安ければ壊れてても気にしねーや！」って感覚だったのと、ガジェット趣味を始めたころは中学生だったので金銭のリソースも限りなく限られていたのがきっかけでジャンク品を今でも見つけると定期的に買ってしまうのですが、ThinkはIBM時代からメーカー公式でパーツ取り寄せも出来ますし、完全部品取りコンディションのジャンクから自分で修理できるのでそれも楽しいんですよね！わかります！</p>\n<p>PC購入はしばらくお休みしようと思っているのですが、多分また気になるものがあったら衝動買いすると思うので定期的に紹介していこうと思います！X1c Gen 9はナオセルならちゃんと直して使ってあげる予定です･･･</p>'}
# ---------------------------------
# each link:https://win-tab.net/misc/junk_diary_
://win-tab.net/android/oukitel_rt7_titan_5g_2308062/#comment-62229
# published:  Fri, 30 Aug 2024 05:17:48 +0000
# title:  HB より OUKITEL RT7 Titan 5G － やべえ、欲しい！現時点で最強のタフネスタブレット（人によっては最凶かも…） へのコメント
# link:  https://win-tab.net/android/oukitel_rt7_titan_5g_2308062/#comment-62229
# content:  {'type': 'text/html', 'language': None, 'base': 'https://win-tab.net/comments/feed/', 'value': '<p>発売後1年経っていますが、いまＡｍａｚｏｎのスマイルセールで28900円で買えるので買ってしまいました。<br />\nお風呂タブ＆災害用バッテリーとしての活躍を期待しています。</p>'}
# ---------------------------------
# each link:https://win-tab.net/acc/logicool_trackball_2408282/#comment-62228
# published:  Fri, 30 Aug 2024 03:08:14 +0000
# title:  匿名 より Logicool MX ERGO S / ERGO M575SP － トラックボールの「名機」2機種がリニューアル、静音タイプに！ へのコメント
# link:  https://win-tab.net/acc/logicool_trackball_2408282/#comment-62228
# content:  {'type': 'text/html', 'language': None, 'base': 'https://win-tab.net/comments/feed/', 'value': '<p>MX ERGO待望のモデルチェンジ……と思ったら静音ボタン採用と充電口がType-Cになった以外はほとんど据え置きかやや劣化……<br />\nフラグシップモデルを名乗る高級機なのだから、MagSpeedホイールくらいは付けて欲しかったですね</p>'}
# ---------------------------------

# %%
for key, value in feed.entries[7].items():
    print(f"Key: {key}, Value: {value}")
# Out:
# Key: title, Value: wintab より Logicool MX ERGO S / ERGO M575SP － トラックボールの「名機」2機種がリニューアル、静音タイプに！ へのコメント
# Key: title_detail, Value: {'type': 'text/plain', 'language': None, 'base': 'https://win-tab.net/comments/feed/', 'value': 'wintab より Logicool MX ERGO S / ERGO M575SP － トラックボールの「名機」2機種がリニューアル、静音タイプに！ へのコメント'}
# Key: links, Value: [{'rel': 'alternate', 'type': 'text/html', 'href': 'https://win-tab.net/acc/logicool_trackball_2408282/#comment-62233'}]
# Key: link, Value: https://win-tab.net/acc/logicool_trackball_2408282/#comment-62233
# Key: authors, Value: [{'name': 'wintab'}]
# Key: author, Value: wintab
# Key: author_detail, Value: {'name': 'wintab'}
# Key: published, Value: Fri, 30 Aug 2024 10:00:48 +0000
# Key: published_parsed, Value: time.struct_time(tm_year=2024, tm_mon=8, tm_mday=30, tm_hour=10, tm_min=0, tm_sec=48, tm_wday=4, tm_yday=243, tm_isdst=0)
# Key: id, Value: https://win-tab.net/?p=157348#comment-62233
# Key: guidislink, Value: False
# Key: summary, Value: こんにちは。すでにMX ERGOをお使いなんですね。私はERGOは使ったことがありませんけど、ロジクールのMXシリーズは大好きです。というか信頼してます。でも、MXシリーズには意外に快適装備って少ないですよね。
# Key: summary_detail, Value: {'type': 'text/html', 'language': None, 'base': 'https://win-tab.net/comments/feed/', 'value': 'こんにちは。すでにMX ERGOをお使いなんですね。私はERGOは使ったことがありませんけど、ロジクールのMXシリーズは大好きです。というか信頼してます。でも、MXシリーズには意外に快適装備って少ないですよね。'}
# Key: content, Value: [{'type': 'text/html', 'language': None, 'base': 'https://win-tab.net/comments/feed/', 'value': '<p>こんにちは。すでにMX ERGOをお使いなんですね。私はERGOは使ったことがありませんけど、ロジクールのMXシリーズは大好きです。というか信頼してます。でも、MXシリーズには意外に快適装備って少ないですよね。</p>'}]

# %%
for items in feed:
    for key, value in items:
        print(f"Key: {key}, Value: {value}")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[6], line 2
#       1 for items in feed:
# ----> 2     for key, value in items:
#       3         print(f"Key: {key}, Value: {value}")
#
# ValueError: not enough values to unpack (expected 2, got 1)

# %%
feed
